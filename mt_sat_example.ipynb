% %% [markdown]
% # 1 Initialize qMRLab

% %%
cd('qMRLab');
startup;
% Out:
% error: qMRLab: No such file or directory
% loading struct
% loading optim
% loading io
% loading statistics
% loading image

% %% [markdown]
% # 2 Download and Run MTsat Demo

% %%
qMRgenBatch(mt_sat,pwd); 
mt_sat_batch
% Out:
% ...
%     fieldnames at line 47 column 11
%     qMRgenBatch at line 16 column 12
% Please wait. Downloading data ...
% ...
%     qMRgenBatch>prot2CLI at line 259 column 17
%     qMRgenBatch at line 71 column 31
% ...
%     qMRgenBatch>prot2CLI at line 259 column 17
%     qMRgenBatch at line 71 column 31
% ...
%     qMRgenBatch>prot2CLI at line 259 column 17
%     qMRgenBatch at line 71 column 31
% ans = 1
% ans = 1
% ans = 1
% ...
%     qMRgenBatch at line 117 column 5
% ------------------------------
% SAVED: mt_sat_batch.m
% Demo is ready at: /home/jovyan/work/qMRLab/mt_sat_demo
% ------------------------------
% Sorry, not implemented for Octave yet. Please contribute on github.com/neuropoly/qMRLab
%
% WARN:	Warning Dialog
% 	Graphical user interface not available on octave... use command lines instead
%
% ans = 1
% ans = 1
% ans = 1
% Sorry, not implemented for Octave yet. Please contribute on github.com/neuropoly/qMRLab
%
% ERROR:	Input Error
% 	Cannot find required input called B1map
%
% ...done
% ...
% ans = 1
% ...
